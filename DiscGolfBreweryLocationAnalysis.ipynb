# %% [markdown]
# # Coursera Capstone

# %% [markdown]
# ## Disc Golf and Brewery Location Analysis

# %% [markdown]
# Disc Golf venues in the United States are popular places for small groups of people to enjoy the great outdoors. What do they need after being outside and enjoying camaraderie? Some refreshments of course. Small local breweries are growing and growing in the United States also. This analysis will find established Disc Golf venues that do not have a Brewery within walking distance and propose examining those sites to build a brewery. The idea is to present a list of potential locations for a brewery to potential brewery owners to conduct further analysis on.

# %% [markdown]
# ## Data

# %% [markdown]
# We will be using data from the US Census Bureau to find cities to analyze and we will match that data up with Foursquare’s venue data.

# %% [markdown]
# ### Obtain Population and Location data from the US Census Bureau

# %%
import requests
import pandas

# %%
census_source = requests.get('https://worldpopulationreview.com/us-cities/#cities').text

# %%
census_rawdata = pandas.read_html(census_source)

# %%
census_moddata = census_rawdata[0]

# %%
censusdf = pandas.DataFrame.from_records(census_moddata)

# %%
censusdf.head()
# Out:
#    Rank         Name       State  2020 Population  2010 Census  Change  \
# 0     1     New York    New York          8622357    8175133.0   0.25%
# 1     2  Los Angeles  California          4085014    3792621.0   0.67%
# 2     3      Chicago    Illinois          2670406    2695598.0  -0.32%
# 3     4      Houston       Texas          2378146    2099451.0   0.79%
# 4     5      Phoenix     Arizona          1743469    1445632.0   1.88%
#
#   2020 Density Latitude/Longitude  Area (kmÂ²)
# 0  11,084/kmÂ²       40.66/-73.94          778
# 1   3,365/kmÂ²      34.02/-118.41         1214
# 2   4,535/kmÂ²       41.84/-87.68          589
# 3   1,443/kmÂ²       29.79/-95.39         1649
# 4   1,300/kmÂ²      33.57/-112.09         1341

# %% [markdown]
# ### Clean the Census Bureau data

# %%
censusdf = censusdf.rename(columns={"Area (kmÂ²)":"Area(km)"})

# %%
censusdf = censusdf.replace(to_replace='/kmÂ²', value='/km2', regex=True)

# %% [markdown]
# ### Population Analysis

# %%
censusdf['2020 Population'].describe()
# Out:
# count    2.000000e+02
# mean     4.162974e+05
# std      7.315589e+05
# min      1.350430e+05
# 25%      1.764738e+05
# 50%      2.255200e+05
# 75%      3.945832e+05
# max      8.622357e+06
# Name: 2020 Population, dtype: float64

# %% [markdown]
# #### *The middle 50% of cities' population range from 176,473 to 394,583.*
# #### *We will therefore conduct our analysis on cities with a population range between 175,000 and 400,000*

# %%
censusdf_trimmed = censusdf[(censusdf['2020 Population'] >= 175000) & (censusdf['2020 Population'] <= 400000)]

# %%
censusdf_trimmed.head()
# Out:
#     Rank         Name       State  2020 Population  2010 Census  Change  \
# 49    50  New Orleans   Louisiana           398523     343829.0   0.44%
# 50    51      Wichita      Kansas           393270     382368.0   0.21%
# 51    52  Bakersfield  California           391996     347483.0   1.01%
# 52    53    Cleveland        Ohio           377797     396815.0  -0.53%
# 53    54       Aurora    Colorado           375326     325078.0   0.92%
#
#    2020 Density Latitude/Longitude  Area(km)
# 49      908/km2       30.05/-89.93       439
# 50      945/km2       37.69/-97.35       416
# 51    1,011/km2      35.35/-119.04       388
# 52    1,877/km2       41.48/-81.68       201
# 53      944/km2      39.69/-104.69       398

# %% [markdown]
# #### Split the Latitidue and Longitude column into two different columns

# %%
censusdf_trimmed[['Latitude', 'Longitude']] = censusdf_trimmed['Latitude/Longitude'].str.split("/", expand=True)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
censusdf_final = censusdf_trimmed[['Name','State','2020 Population','Latitude','Longitude','Area(km)','2020 Density']]

# %%
censusdf_final.head()
# Out:
#            Name       State  2020 Population Latitude Longitude  Area(km)  \
# 49  New Orleans   Louisiana           398523    30.05    -89.93       439
# 50      Wichita      Kansas           393270    37.69    -97.35       416
# 51  Bakersfield  California           391996    35.35   -119.04       388
# 52    Cleveland        Ohio           377797    41.48    -81.68       201
# 53       Aurora    Colorado           375326    39.69   -104.69       398
#
#    2020 Density
# 49      908/km2
# 50      945/km2
# 51    1,011/km2
# 52    1,877/km2
# 53      944/km2

# %%
CLIENT_ID = 'EA3ER2PLBUQRTW1XH0CZADJRLEJ4D0RNO0EOCV2CQUEOE51G' # your Foursquare ID
CLIENT_SECRET = 'F3PNFMJAR04XR5ASLDK2RNP150GRMOSISR20KSKFCPPA00ZV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
CATEGORY_ID = '52e81612bcbc57f1066b79e8' # Disc Golf Category

# %%
def getVenues(names, latitudes, longitudes):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        # create the API request URL
        url ='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            CATEGORY_ID)

        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name,
            lat, 
            lng, 
            v['venue']['name'],
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])

    venuesdf = pandas.DataFrame([item for venue_list in venues_list for item in venue_list])
    venuesdf.columns = ['City', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue',
                  'VenueID',
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue Category']
    return(venuesdf)

# %% [markdown]
# ### Obtain Foursquare data using the Cities we are interested in and focusing on the Disc Golf category

# %%
city_venues = getVenues(names=censusdf_final['Name'],
                                   latitudes=censusdf_final['Latitude'],
                                   longitudes=censusdf_final['Longitude']
                                  )
# Out:
# New Orleans
# Wichita
# Bakersfield
# Cleveland
# Aurora
# Anaheim
# Honolulu
# Riverside
# Santa Ana
# Lexington
# Corpus Christi
# Henderson
# Stockton
# St. Paul
# Irvine
# Orlando
# Pittsburgh
# Cincinnati
# Anchorage
# St. Louis
# Plano
# Lincoln
# Greensboro
# Durham
# Newark
# St. Petersburg
# Chula Vista
# Toledo
# Scottsdale
# Fort Wayne
# Madison
# Lubbock
# Laredo
# Jersey City
# Reno
# Chandler
# North Las Vegas
# Glendale
# Gilbert
# Buffalo
# Winston Salem
# Chesapeake
# Irving
# Norfolk
# Fremont
# Richmond
# Boise
# Hialeah
# Garland
# Spokane
# Tacoma
# Baton Rouge
# Fontana
# Modesto
# San Bernardino
# Des Moines
# Moreno Valley
# Oxnard
# Mckinney
# Birmingham
# Fayetteville
# Port St. Lucie
# Rochester
# Amarillo
# Grand Prairie
# Salt Lake City
# Yonkers
# Frisco
# Grand Rapids
# Huntsville
# Tempe
# Overland Park
# Little Rock
# Cape Coral
# Huntington Beach
# Augusta
# Montgomery
# Tallahassee
# Akron
# Mobile
# Knoxville
# Brownsville
# Shreveport
# Sioux Falls
# Worcester
# Santa Clarita
# Vancouver
# Rancho Cucamonga
# Elk Grove
# Fort Lauderdale
# Ontario
# Chattanooga
# Newport News
# Salem
# Providence
# Corona
# Peoria
# Eugene
# Santa Rosa
# Oceanside
# Pembroke Pines
# Garden Grove

# %%
city_venues.head()
# Out:
#           City City Latitude City Longitude                            Venue  \
# 0  New Orleans         30.05         -89.93       City Park Disc Golf Course
# 1  New Orleans         30.05         -89.93  Lafreiere Park Disc Golf Course
# 2      Wichita         37.69         -97.35                  Disc Golf Mania
# 3      Wichita         37.69         -97.35        Oak Park Disc Golf Course
# 4      Wichita         37.69         -97.35                 Herman Hill Park
#
#                     VenueID  Venue Latitude  Venue Longitude Venue Category
# 0  4d6033c7338bb60cdf8f25bd       29.991785       -90.093531      Disc Golf
# 1  4e542bbb1495ac3f02313e42       30.000182       -90.208831      Disc Golf
# 2  4bb9eb01b35776b0b247ca01       37.704375       -97.347938      Disc Golf
# 3  4e651cebb0fb188e8ed6d8c3       37.711936       -97.359596      Disc Golf
# 4  4cee5623d29b2d435383edbb       37.648780       -97.338910           Park

# %%
city_venues['Venue Category'].value_counts()
# Out:
# Disc Golf              422
# Park                    41
# Golf Course              4
# Sporting Goods Shop      3
# Trail                    1
# Campground               1
# Athletics & Sports       1
# Name: Venue Category, dtype: int64

# %% [markdown]
# #### Combine our Foursquare and Census data

# %%
combined_df = pandas.merge(city_venues, censusdf_final[['Name','State','2020 Population','Area(km)', '2020 Density']], left_on='City', right_on='Name', how='left')

# %%
combined_df.drop('Name', axis=1, inplace=True)

# %%
combined_df.head()
# Out:
#           City City Latitude City Longitude                            Venue  \
# 0  New Orleans         30.05         -89.93       City Park Disc Golf Course
# 1  New Orleans         30.05         -89.93  Lafreiere Park Disc Golf Course
# 2      Wichita         37.69         -97.35                  Disc Golf Mania
# 3      Wichita         37.69         -97.35        Oak Park Disc Golf Course
# 4      Wichita         37.69         -97.35                 Herman Hill Park
#
#                     VenueID  Venue Latitude  Venue Longitude Venue Category  \
# 0  4d6033c7338bb60cdf8f25bd       29.991785       -90.093531      Disc Golf
# 1  4e542bbb1495ac3f02313e42       30.000182       -90.208831      Disc Golf
# 2  4bb9eb01b35776b0b247ca01       37.704375       -97.347938      Disc Golf
# 3  4e651cebb0fb188e8ed6d8c3       37.711936       -97.359596      Disc Golf
# 4  4cee5623d29b2d435383edbb       37.648780       -97.338910           Park
#
#        State  2020 Population  Area(km) 2020 Density
# 0  Louisiana           398523       439      908/km2
# 1  Louisiana           398523       439      908/km2
# 2     Kansas           393270       416      945/km2
# 3     Kansas           393270       416      945/km2
# 4     Kansas           393270       416      945/km2

# %% [markdown]
# #### Clean the data by removing categories not specific to Disc Golf

# %%
dgolfdf = combined_df[combined_df['Venue Category'].str.contains('Disc Golf')]

# %%
dgolfdf
# Out:
#              City City Latitude City Longitude  \
# 0     New Orleans         30.05         -89.93
# 1     New Orleans         30.05         -89.93
# 2         Wichita         37.69         -97.35
# 3         Wichita         37.69         -97.35
# 5         Wichita         37.69         -97.35
# ..            ...           ...            ...
# 468  Garden Grove         33.78        -117.96
# 469  Garden Grove         33.78        -117.96
# 470  Garden Grove         33.78        -117.96
# 471  Garden Grove         33.78        -117.96
# 472  Garden Grove         33.78        -117.96
#
#                                          Venue                   VenueID  \
# 0                   City Park Disc Golf Course  4d6033c7338bb60cdf8f25bd
# 1              Lafreiere Park Disc Golf Course  4e542bbb1495ac3f02313e42
# 2                              Disc Golf Mania  4bb9eb01b35776b0b247ca01
# 3                    Oak Park Disc Golf Course  4e651cebb0fb188e8ed6d8c3
# 5                 Stone Creek Disc Golf Course  4be347a7f07b0f47689af743
# ..                                         ...                       ...
# 468                 La Mirada Disc Golf Course  4c3ce304a97bbe9aca21fbdd
# 469                 El Dorado Disc Golf Course  4b48d7f0f964a5209c5926e3
# 470              Liberty Park Disc Golf Course  527fcf5711d242393c093f4b
# 471                  Cerritos Disc Golf Course  4df3e3a5d1649c8a28e4c758
# 472  Deerfield Community Park/Disc Golf Course  4bef36665e4aa59370bd58bb
#
#      Venue Latitude  Venue Longitude Venue Category       State  \
# 0         29.991785       -90.093531      Disc Golf   Louisiana
# 1         30.000182       -90.208831      Disc Golf   Louisiana
# 2         37.704375       -97.347938      Disc Golf      Kansas
# 3         37.711936       -97.359596      Disc Golf      Kansas
# 5         37.577079       -97.262254      Disc Golf      Kansas
# ..              ...              ...            ...         ...
# 468       33.905737      -118.006026      Disc Golf  California
# 469       33.808632      -118.098754      Disc Golf  California
# 470       33.857988      -118.089426      Disc Golf  California
# 471       33.857028      -118.100967      Disc Golf  California
# 472       33.690114      -117.791942      Disc Golf  California
#
#      2020 Population  Area(km) 2020 Density
# 0             398523       439      908/km2
# 1             398523       439      908/km2
# 2             393270       416      945/km2
# 3             393270       416      945/km2
# 5             393270       416      945/km2
# ..               ...       ...          ...
# 468           175618        47    3,776/km2
# 469           175618        47    3,776/km2
# 470           175618        47    3,776/km2
# 471           175618        47    3,776/km2
# 472           175618        47    3,776/km2
#
# [422 rows x 12 columns]

# %% [markdown]
# #### Foursquare has given us duplicate venues as evidenced by the VenueID. We now remove those duplicates

# %%
dgolfdf.drop_duplicates(subset ='VenueID', 
                     keep = 'first', inplace = True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dgolfdf
# Out:
#                City City Latitude City Longitude  \
# 0       New Orleans         30.05         -89.93
# 1       New Orleans         30.05         -89.93
# 2           Wichita         37.69         -97.35
# 3           Wichita         37.69         -97.35
# 5           Wichita         37.69         -97.35
# ..              ...           ...            ...
# 457       Oceanside         33.22        -117.31
# 458       Oceanside         33.22        -117.31
# 459       Oceanside         33.22        -117.31
# 460       Oceanside         33.22        -117.31
# 461  Pembroke Pines         26.02         -80.34
#
#                                                  Venue  \
# 0                           City Park Disc Golf Course
# 1                      Lafreiere Park Disc Golf Course
# 2                                      Disc Golf Mania
# 3                            Oak Park Disc Golf Course
# 5                         Stone Creek Disc Golf Course
# ..                                                 ...
# 457  Google Terrace Park Connecticut disc golf hole...
# 458                   Brengle Terrace Disc Golf Course
# 459                      Montiel Park Disc Golf Course
# 460                                    CSUSM Disc Golf
# 461                      markham park disc golf course
#
#                       VenueID  Venue Latitude  Venue Longitude Venue Category  \
# 0    4d6033c7338bb60cdf8f25bd       29.991785       -90.093531      Disc Golf
# 1    4e542bbb1495ac3f02313e42       30.000182       -90.208831      Disc Golf
# 2    4bb9eb01b35776b0b247ca01       37.704375       -97.347938      Disc Golf
# 3    4e651cebb0fb188e8ed6d8c3       37.711936       -97.359596      Disc Golf
# 5    4be347a7f07b0f47689af743       37.577079       -97.262254      Disc Golf
# ..                        ...             ...              ...            ...
# 457  5181cb77498eb457e312c9a9       33.203842      -117.230995      Disc Golf
# 458  4ff84fe3e4b0f1c618fbbbe8       33.209847      -117.221780      Disc Golf
# 459  4bdb5e653904a5934c0e4a9e       33.131542      -117.114023      Disc Golf
# 460  4c3e44d080bc20a164ccaa58       33.131623      -117.159290      Disc Golf
# 461  52ee81f5498e20d619cbe7c8       26.131325       -80.346965      Disc Golf
#
#           State  2020 Population  Area(km) 2020 Density
# 0     Louisiana           398523       439      908/km2
# 1     Louisiana           398523       439      908/km2
# 2        Kansas           393270       416      945/km2
# 3        Kansas           393270       416      945/km2
# 5        Kansas           393270       416      945/km2
# ..          ...              ...       ...          ...
# 457  California           176800       107    1,655/km2
# 458  California           176800       107    1,655/km2
# 459  California           176800       107    1,655/km2
# 460  California           176800       107    1,655/km2
# 461     Florida           176759        86    2,066/km2
#
# [320 rows x 12 columns]

# %% [markdown]
# #### Definition of walking distance is from Wikipedia;
# https://en.wikipedia.org/wiki/Walking_distance_measure
# #### 80 meters per minute and the commonly accepted 10-15 minute walk. So we will limit searches to within 1000 meters of our disc golf venue. 1000 meters woud be a 12.5 minute walk.

# %%
# Brewery category ID
CATEGORY_ID = '50327c8591d4c4b30a586d5d'

# %%
def getNearbyBreweries(names, latitudes, longitudes, radius=1000):
    
    potential_locations_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        # create the API request URL
        url ='https://api.foursquare.com/v2/venues/search/?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&intent=checkin'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius,
            CATEGORY_ID)

        # make the GET request
        results = requests.get(url).json()['response']['venues']
        # build the dataframe with disc golf venues that don't have a brewery within walking distance
        if len(results) == 0:
            potential_locations_list.append([(name,lat,lng)])
            potential_locations_df = pandas.DataFrame([item for location_list in potential_locations_list for item in location_list])
            potential_locations_df.columns = ['Venue', 'Venue Latitude','Venue Longitude']

    return(potential_locations_df)

# %% [markdown]
# #### We now filter our list of Disc Golf venues by querying Foursquare to find Disc Golf venues that do not have an already established Brewery within walkng distance defined as within 1000 meters

# %%
potential_venues = getNearbyBreweries(names=dgolfdf['Venue'],
                                      latitudes=dgolfdf['Venue Latitude'],
                                      longitudes=dgolfdf['Venue Longitude']
                                  )
# Out:
# City Park Disc Golf Course
# Lafreiere Park Disc Golf Course
# Disc Golf Mania
# Oak Park Disc Golf Course
# Stone Creek Disc Golf Course
# Hart Park Disc Golf (The Flats)
# Shark Tooth Mountain Disc Golf Course
# Parma Disc Golf Course
# Lakeview Church Disc Golf Course
# Tri-C Disc Golf Course
# Parma Disc Golf
# Expo Disc Golf
# Greenwood Village Disc Golf Course
# 'The Dock' Disc Golf Course - Dry Dock North
# Green Valley Ranch Disc Golf Course
# Westcreek Disc Golf Course
# Lighthouse Disc Golf Course
# Lakewood Dry Gulch Disc Golf Course
# CHU Disc Golf
# Arapahoe Community College Disc Golf Course
# Badlands Disc Golf Course
# Adams Hollow Disc Golf Course
# Springvale Park Disc Golf Course
# Schaefer Disc Golf
# Disc Golf At Matney Park
# Twila Reid Park (Disc Golf Course)
# 2                   Oak Park Disc Golf Course       37.711936       -97.359596
# 3                Stone Creek Disc Golf Course       37.577079       -97.262254
# 4             Hart Park Disc Golf (The Flats)       35.446677      -118.912993
# ..                                        ...             ...              ...
# 254              crane creek disc golf course       38.341822      -122.698517
# 255  Kinetic Disc Golf - Brengle Terrace Park       33.209775      -117.222538
# 256          Brengle Terrace Disc Golf Course       33.209847      -117.221780
# 257             Montiel Park Disc Golf Course       33.131542      -117.114023
# 258             markham park disc golf course       26.131325       -80.346965
#
# [259 rows x 3 columns]

# %% [markdown]
# #### Merge the Disc Golf venues with no nearby Brewery with out Census data

# %%
finaldf = pandas.merge(potential_venues, dgolfdf)

# %%
finaldf.sort_values(['State', '2020 Population'])
# Out:
#                                                  Venue  Venue Latitude  \
# 214                              MUNI disc Golf Course       30.707131
# 215                               Down South Disc Golf       30.599817
# 216                      Steele Creek Disc Golf Course       30.857668
# 217                          Fairhope Disc Golf Course       30.541020
# 210                                      AUM Disc Golf       32.365859
# ..                                                 ...             ...
# 94                               Token Creek Disc Golf       43.176738
# 95                                     Glide Disc Golf       43.099062
# 96   Capital Springs Recreational Area Disc Golf Co...       43.022267
# 97                       Vallarta-Ast Disc Golf Course       43.176758
# 98                         Door Creek Disc Golf Course       43.091300
#
#      Venue Longitude        City City Latitude City Longitude  \
# 214       -88.161564      Mobile         30.67         -88.10
# 215       -87.902813      Mobile         30.67         -88.10
# 216       -88.039450      Mobile         30.67         -88.10
# 217       -87.887968      Mobile         30.67         -88.10
# 210       -86.173768  Montgomery         32.35         -86.27
# ..               ...         ...           ...            ...
# 94        -89.315491     Madison         43.09         -89.43
# 95        -89.311073     Madison         43.09         -89.43
# 96        -89.350753     Madison         43.09         -89.43
# 97        -89.315520     Madison         43.09         -89.43
# 98        -89.262650     Madison         43.09         -89.43
#
#                       VenueID Venue Category      State  2020 Population  \
# 214  4c2bab18ae6820a1a52e1843      Disc Golf    Alabama           190948
# 215  535a3f3b498e175cb0c0c8a4      Disc Golf    Alabama           190948
# 216  510d9e63e4b00423da003658      Disc Golf    Alabama           190948
# 217  4dd2f0eae4cd1b19130d71d7      Disc Golf    Alabama           190948
# 210  4b92a988f964a520f90e34e3      Disc Golf    Alabama           196442
# ..                        ...            ...        ...              ...
# 94   4dd93ed82271c5d36d671fb5      Disc Golf  Wisconsin           268303
# 95   4c5595cd06901b8dc1d4bb4d      Disc Golf  Wisconsin           268303
# 96   51d57123498e621174d5ff41      Disc Golf  Wisconsin           268303
# 97   4c14d3bf7f7f2d7fdf6ae168      Disc Golf  Wisconsin           268303
# 98   59948ba073fe252c11a051f4      Disc Golf  Wisconsin           268303
#
#      Area(km) 2020 Density
# 214       361      529/km2
# 215       361      529/km2
# 216       361      529/km2
# 217       361      529/km2
# 210       414      475/km2
# ..        ...          ...
# 94        199    1,345/km2
# 95        199    1,345/km2
# 96        199    1,345/km2
# 97        199    1,345/km2
# 98        199    1,345/km2
#
# [259 rows x 12 columns]

# %% [markdown]
# #### The final dataframe gives us 259 potential locations to build a Brewery near
